# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
#  YOUR CODE GOES HERE
charity = pd.read_csv("charity_data.csv").drop(columns=["EIN", "NAME"])
charity
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
charity.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
charity["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
charity["APPLICATION_TYPE"].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#  YOUR CODE GOES HERE
application_types_to_replace = [9, 13, 12, 2, 29, 25, 14, 15, 17]

# Replace in dataframe
for app in application_types_to_replace:
    charity['APPLICATION_TYPE'] = charity['APPLICATION_TYPE'].replace("T"+str(app),"Other")

# Check to make sure binning was successful
charity['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
#  YOUR CODE GOES HERE
charity["CLASSIFICATION"].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
#  YOUR CODE GOES HERE
charity["CLASSIFICATION"].value_counts()[charity["CLASSIFICATION"].value_counts()>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#  YOUR CODE GOES HERE
classifications_to_replace = charity["CLASSIFICATION"].value_counts()[charity["CLASSIFICATION"].value_counts()<99].index

# Replace in dataframe
for cls in classifications_to_replace:
    charity['CLASSIFICATION'] = charity['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
charity['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# Other      669
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
#  YOUR CODE GOES HERE
charity_dummy = pd.get_dummies(charity)
charity_dummy
# Out:
#        STATUS   ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0           1      5000              1                       0
# 1           1    108590              1                       0
# 2           1      5000              0                       0
# 3           1      6692              1                       0
# 4           1    142590              1                       0
# ...       ...       ...            ...                     ...
# 34294       1      5000              0                       0
# 34295       1      5000              0                       0
# 34296       1      5000              0                       0
# 34297       1      5000              1                       0
# 34298       1  36500179              0                       0
#
#        APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                         1                     0                    0
# 1                         0                     0                    1
# 2                         0                     0                    0
# 3                         0                     0                    1
# 4                         0                     0                    1
# ...                     ...                   ...                  ...
# 34294                     0                     0                    0
# 34295                     0                     0                    0
# 34296                     0                     0                    1
# 34297                     0                     0                    0
# 34298                     0                     0                    1
#
#        APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                        0                    0                    0  ...
# 1                        0                    0                    0  ...
# 2                        0                    1                    0  ...
# 3                        0                    0                    0  ...
# 4                        0                    0                    0  ...
# ...                    ...                  ...                  ...  ...
# 34294                    1                    0                    0  ...
# 34295                    1                    0                    0  ...
# 34296                    0                    0                    0  ...
# 34297                    0                    1                    0  ...
# 34298                    0                    0                    0  ...
#
#        INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0                      0                       0                         0
# 1                      1                       0                         0
# 2                      0                       0                         0
# 3                      0                       1                         0
# 4                      0                       0                         1
# ...                  ...                     ...                       ...
# 34294                  0                       0                         0
# 34295                  0                       0                         0
# 34296                  0                       0                         0
# 34297                  0                       0                         0
# 34298                  0                       0                         0
#
#        INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0                       0                 0                       0
# 1                       0                 0                       0
# 2                       0                 0                       0
# 3                       0                 0                       0
# 4                       0                 0                       0
# ...                   ...               ...                     ...
# 34294                   0                 0                       0
# 34295                   0                 0                       0
# 34296                   0                 0                       0
# 34297                   0                 0                       0
# 34298                   0                 1                       0
#
#        INCOME_AMT_50M+  INCOME_AMT_5M-10M  SPECIAL_CONSIDERATIONS_N  \
# 0                    0                  0                         1
# 1                    0                  0                         1
# 2                    0                  0                         1
# 3                    0                  0                         1
# 4                    0                  0                         1
# ...                ...                ...                       ...
# 34294                0                  0                         1
# 34295                0                  0                         1
# 34296                0                  0                         1
# 34297                0                  0                         1
# 34298                0                  0                         1
#
#        SPECIAL_CONSIDERATIONS_Y
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
# ...                         ...
# 34294                         0
# 34295                         0
# 34296                         0
# 34297                         0
# 34298                         0
#
# [34299 rows x 50 columns]

# %%
# Split our preprocessed data into our features and target arrays
#  YOUR CODE GOES HERE
y = charity_dummy["IS_SUCCESSFUL"].values
X = charity_dummy.drop(["IS_SUCCESSFUL"],1).values
# Split the preprocessed data into a training and testing dataset
#  YOUR CODE GOES HERE
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   after removing the cwd from sys.path.

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 8
hidden_nodes_layer2 = 5

nn = tf.keras.models.Sequential()

# First hidden layer
#  YOUR CODE GOES HERE
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim = number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))
#  YOUR CODE GOES HERE

# Output layer
#  YOUR CODE GOES HERE
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 8)                 400
#
#  dense_1 (Dense)             (None, 5)                 45
#
#  dense_2 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 451
# Trainable params: 451
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
#  YOUR CODE GOES HERE
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
#  YOUR CODE GOES HERE
fit_model = nn.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.6224 - accuracy: 0.6794
# Epoch 2/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5826 - accuracy: 0.7163
# Epoch 3/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5690 - accuracy: 0.7236
# Epoch 4/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5608 - accuracy: 0.7257
# Epoch 5/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5574 - accuracy: 0.7263
# Epoch 6/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5549 - accuracy: 0.7273
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5534 - accuracy: 0.7280
# Epoch 8/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5523 - accuracy: 0.7287
# Epoch 9/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5513 - accuracy: 0.7283
# Epoch 10/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5504 - accuracy: 0.7289
# Epoch 11/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5499 - accuracy: 0.7296
# Epoch 12/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5496 - accuracy: 0.7297
# Epoch 13/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5492 - accuracy: 0.7293
# Epoch 14/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5489 - accuracy: 0.7299
# Epoch 15/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5484 - accuracy: 0.7310
# Epoch 16/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5486 - accuracy: 0.7308
# Epoch 17/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5480 - accuracy: 0.7295
# Epoch 18/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5480 - accuracy: 0.7310
# Epoch 19/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5481 - accuracy: 0.7301
# Epoch 20/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5478 - accuracy: 0.7308
# Epoch 21/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5472 - accuracy: 0.7304
# Epoch 22/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5472 - accuracy: 0.7302
# Epoch 23/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5471 - accuracy: 0.7297
# Epoch 24/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5469 - accuracy: 0.7288
# Epoch 25/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5464 - accuracy: 0.7296
# Epoch 26/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5468 - accuracy: 0.7304
# Epoch 27/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5465 - accuracy: 0.7313
# Epoch 28/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5466 - accuracy: 0.7306
# Epoch 29/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5467 - accuracy: 0.7289
# Epoch 30/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5462 - accuracy: 0.7313
# Epoch 31/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5463 - accuracy: 0.7308
# Epoch 32/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5460 - accuracy: 0.7322
# Epoch 33/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5461 - accuracy: 0.7315
# Epoch 34/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5460 - accuracy: 0.7307
# Epoch 35/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5461 - accuracy: 0.7313
# Epoch 36/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7313
# Epoch 37/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7316
# Epoch 38/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7310
# Epoch 39/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7315
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7315
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7316
# Epoch 42/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5456 - accuracy: 0.7330
# Epoch 43/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5458 - accuracy: 0.7322
# Epoch 44/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7313
# Epoch 45/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5451 - accuracy: 0.7327
# Epoch 46/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5454 - accuracy: 0.7320
# Epoch 47/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5452 - accuracy: 0.7329
# Epoch 48/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5450 - accuracy: 0.7325
# Epoch 49/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5453 - accuracy: 0.7320
# Epoch 50/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5450 - accuracy: 0.7316
# Epoch 51/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7318
# Epoch 52/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5449 - accuracy: 0.7324
# Epoch 53/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5448 - accuracy: 0.7328
# Epoch 54/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5447 - accuracy: 0.7337
# Epoch 55/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7338
# Epoch 56/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7331
# Epoch 57/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5445 - accuracy: 0.7322
# Epoch 58/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5446 - accuracy: 0.7339
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7318
# Epoch 60/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7323
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5442 - accuracy: 0.7337
# Epoch 62/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7325
# Epoch 63/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5441 - accuracy: 0.7323
# Epoch 64/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7341
# Epoch 65/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5437 - accuracy: 0.7336
# Epoch 66/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5440 - accuracy: 0.7323
# Epoch 67/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5439 - accuracy: 0.7342
# Epoch 68/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5436 - accuracy: 0.7339
# Epoch 69/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7340
# Epoch 70/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7332
# Epoch 71/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5436 - accuracy: 0.7336
# Epoch 72/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5434 - accuracy: 0.7327
# Epoch 73/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5438 - accuracy: 0.7329
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.7343
# Epoch 75/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5431 - accuracy: 0.7342
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7336
# Epoch 77/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5431 - accuracy: 0.7338
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7340
# Epoch 79/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.7332
# Epoch 80/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7340
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7347
# Epoch 82/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7342
# Epoch 83/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7341
# Epoch 84/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7340
# Epoch 85/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7347
# Epoch 86/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5428 - accuracy: 0.7345
# Epoch 87/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5427 - accuracy: 0.7346
# Epoch 88/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5425 - accuracy: 0.7345
# Epoch 89/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7345
# Epoch 90/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7338
# Epoch 91/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7343
# Epoch 92/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5425 - accuracy: 0.7341
# Epoch 93/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5425 - accuracy: 0.7335
# Epoch 94/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5424 - accuracy: 0.7348
# Epoch 95/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5421 - accuracy: 0.7353
# Epoch 96/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5423 - accuracy: 0.7339
# Epoch 97/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5425 - accuracy: 0.7337
# Epoch 98/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5419 - accuracy: 0.7336
# Epoch 99/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5421 - accuracy: 0.7331
# Epoch 100/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5418 - accuracy: 0.7340

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5545 - accuracy: 0.7275 - 459ms/epoch - 2ms/step
# Loss: 0.5544854402542114, Accuracy: 0.7274635434150696

# %%
# Export our model to HDF5 file
#  YOUR CODE GOES HERE
nn.save_weights('my_model.hdf5')
